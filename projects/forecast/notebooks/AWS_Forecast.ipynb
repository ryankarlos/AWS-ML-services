# %%
import os
from pathlib import Path

import pandas as pd
import pandas as pd
from pathlib import Path
import os 
import json
import numpy as np


pd.set_option('display.max_colwidth', None)

# add repo root to beginning of sys path to allow other modules to be found by python import machinery
import sys 
sys.path
ROOT_PATH = os.path.abspath('..')
sys.path.insert(0, ROOT_PATH)

# or instead of above can directly change cur dir path to root - but dont do both ! 
#ROOT_PATH= str(Path(os.getcwd()).parents[0])
#os.chdir(ROOT_PATH)
# os instead of above can directly change cur dir path to root
#ROOT_PATH= str(Path(os.getcwd()).parents[0])
#os.chdir(ROOT_PATH)
print(ROOT_PATH)

RESULTS_DIR = os.path.join(str(Path(ROOT_PATH).parents[1]), 'datasets/forecasting/results')
print(RESULTS_DIR )
# Out:
# /Users/rk1103/Documents/AWS-ML-services/projects/forecast
# /Users/rk1103/Documents/AWS-ML-services/datasets/forecasting/results

# %%
from prepare_data_for_s3 import *
from create_predictor_forecast_jobs import *
from teardown_resources import *
from common import *
from dataset_and_import_jobs import *

# %%
# what is your forecast horizon in number time units you've selected?
FORECAST_LENGTH = 35
# What is your forecast time unit granularity?
DATASET_FREQUENCY = "D"
TIMESTAMP_FORMAT = "yyyy-MM-dd"
# We will use this same name for your Forecast Dataset Group name.
PROJECT = 'manning_ts'
DATA_VERSION = 1
bucket_name = 'aws-forecast-demo-examples'
key = "manning_ts_2015.csv"
dataset_name = f"{PROJECT}_{DATA_VERSION}"
dataset_group = f"{PROJECT}_{DATA_VERSION}"
predictor_name = f"{PROJECT}_{DATA_VERSION}_automl"
forecast_name = f"{PROJECT}_{DATA_VERSION}_automl_forecast"

# Specify the schema of your dataset here. Make sure the order of columns matches the raw data files.
ts_schema ={
   "Attributes":[
      {
         "AttributeName":"timestamp",
         "AttributeType":"timestamp"
      },
      {
         "AttributeName":"target_value",
         "AttributeType":"float"
      },
      {
         "AttributeName":"item_id",
         "AttributeType":"string"
      }
   ]
}

role_name = "AmazonForecast-ExecutionRole-1645141603603"
iam = boto3.client('iam')
role_arn = iam.get_role(RoleName=role_name)['Role']['Arn']

# %%
# load sample manning from prophet github repo and update datasets folder

#pdf = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')
#pdf.to_csv(path)

# %% [markdown]
# #### Local parsing and loading data into S3

# %%
dir_path = str(Path(RESULTS_DIR).parent)
df, basepath = read_raw_csv(dir_path)
df.head()
# Out:
# Reading data from /Users/rk1103/Documents/AWS-ML-services/datasets/forecasting/sample_manning.csv
#    Unnamed: 0          ds         y
# 0           0  2007-12-10  9.590761
# 1           1  2007-12-11  8.519590
# 2           2  2007-12-12  8.183677
# 3           3  2007-12-13  8.072467
# 4           4  2007-12-14  7.893572

# %%
df_parsed = parse_dt_to_year(df)   
df_filtered = filter_df_by_year(df_parsed)   
df_renamed = reformat_for_aws_forecast(df_filtered)   
df_renamed.visualize(filename=f'{dir_path}/example_dask_taskgraph.png')

# %%
df_final = df_renamed.compute()
df_final.iloc[:, :2].plot(x='timestamp', figsize=(15,8), legend=False)
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
dask.array.compute(df_final.shape)[0]
# Out:
# (363, 3)

# %%
filepath = save_data_for_s3(df_final, basepath, filename=key)
# Out:
# /Users/rk1103/Documents/AWS-ML-services/datasets/forecasting/s3_upload/manning_ts_2015.csv

# %% [markdown]
# ### Create AWS Forecast Job

# %%
put_object_in_s3_bucket(bucket_name, filepath)
# Out:
# {'ResponseMetadata': {'RequestId': 'T9W78VQTA57QQ9SJ', 'HostId': 'r9DR/5uFMZuwOioaylf2pgYIA7okM86zPx2xS6v+PA4vtEmp2GWBMhUdrKMz/8PFRKHz0zmy9Vw=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'r9DR/5uFMZuwOioaylf2pgYIA7okM86zPx2xS6v+PA4vtEmp2GWBMhUdrKMz/8PFRKHz0zmy9Vw=', 'x-amz-request-id': 'T9W78VQTA57QQ9SJ', 'date': 'Wed, 04 May 2022 20:01:40 GMT', 'location': '/aws-forecast-demo-examples', 'server': 'AmazonS3', 'content-length': '0'}, 'RetryAttempts': 0}, 'Location': '/aws-forecast-demo-examples'}

# %% [markdown]
# #### Creating Dataset Group and Import Job in AWS Forecast

# %%
# Recall path to your data

dataset_arn = create_dataset(dataset_name, DATASET_FREQUENCY, ts_schema)
dataset_group_arn = create_dataset_group_with_dataset(dataset_name, dataset_arn)

# %%
ts_dataset_import_job_response = create_import_job(bucket_name, key, dataset_arn, role_arn)
# Out:
# S3 URI for your data file = s3://aws-forecast-demo-examples/manning_ts_2015.csv

# %%
dataset_import_job_arn=ts_dataset_import_job_response['DatasetImportJobArn']
check_job_status(dataset_import_job_arn, job_type="import_data")
# Out:
# Import job now complete, ready to start training

# %% [markdown]
# ### Training and Evaluating Backtest

# %%
create_predictor_response , predictor_arn = train_aws_forecast_model(predictor_name, FORECAST_LENGTH, DATASET_FREQUENCY, dataset_group_arn)
check_job_status(predictor_arn, job_type="training")
# Out:
# Training job complete with job status ACTIVE

# %% [markdown]
# #### check config of training job and execution details once complete

# %%
training_job_config, execution_details = get_training_job_config_and_execution_details(predictor_arn)
print(f"Training job configuration:\n\n {training_job_config}")
print("")
print(f"Model execution details:\n\n {execution_details}")
# Out:
# Training job configuration:
#
#  [('ForecastHorizon', 24), ('ForecastTypes', ['0.1', '0.5', '0.9']), ('PerformAutoML', True), ('TrainingParameters', {'context_length': '1100', 'exp_kernel_weights': '0.01', 'kernel_type': 'exponential', 'prediction_length': '24', 'use_default_time_features': 'true', 'use_seasonal_model': 'true'}), ('EvaluationParameters', {'NumberOfBacktestWindows': 1, 'BackTestWindowOffset': 24}), ('InputDataConfig', {'DatasetGroupArn': 'arn:aws:forecast:us-east-1:376337229415:dataset-group/manning_ts_1'}), ('FeaturizationConfig', {'ForecastFrequency': 'D', 'Featurizations': [{'AttributeName': 'target_value', 'FeaturizationPipeline': [{'FeaturizationMethodName': 'filling', 'FeaturizationMethodParameters': {'aggregation': 'sum', 'backfill': 'zero', 'frontfill': 'none', 'middlefill': 'zero'}}]}]}), ('PredictorExecutionDetails', {'PredictorExecutions': [{'AlgorithmArn': 'arn:aws:forecast:::algorithm/ETS', 'TestWindows': [{'TestWindowStart': datetime.datetime(2015, 12, 8, 0, 0, tzinfo=tzlocal()), 'TestWindowEnd': datetime.datetime(2016, 1, 1, 0, 0, tzinfo=tzlocal()), 'Status': 'ACTIVE'}]}, {'AlgorithmArn': 'arn:aws:forecast:::algorithm/CNN-QR', 'TestWindows': [{'TestWindowStart': datetime.datetime(2015, 12, 8, 0, 0, tzinfo=tzlocal()), 'TestWindowEnd': datetime.datetime(2016, 1, 1, 0, 0, tzinfo=tzlocal()), 'Status': 'ACTIVE'}]}, {'AlgorithmArn': 'arn:aws:forecast:::algorithm/NPTS', 'TestWindows': [{'TestWindowStart': datetime.datetime(2015, 12, 8, 0, 0, tzinfo=tzlocal()), 'TestWindowEnd': datetime.datetime(2016, 1, 1, 0, 0, tzinfo=tzlocal()), 'Status': 'ACTIVE'}]}, {'AlgorithmArn': 'arn:aws:forecast:::algorithm/Prophet', 'TestWindows': [{'TestWindowStart': datetime.datetime(2015, 12, 8, 0, 0, tzinfo=tzlocal()), 'TestWindowEnd': datetime.datetime(2016, 1, 1, 0, 0, tzinfo=tzlocal()), 'Status': 'ACTIVE'}]}, {'AlgorithmArn': 'arn:aws:forecast:::algorithm/ARIMA', 'TestWindows': [{'TestWindowStart': datetime.datetime(2015, 12, 8, 0, 0, tzinfo=tzlocal()), 'TestWindowEnd': datetime.datetime(2016, 1, 1, 0, 0, tzinfo=tzlocal()), 'Status': 'ACTIVE'}]}, {'AlgorithmArn': 'arn:aws:forecast:::algorithm/Deep_AR_Plus', 'TestWindows': [{'TestWindowStart': datetime.datetime(2015, 12, 8, 0, 0, tzinfo=tzlocal()), 'TestWindowEnd': datetime.datetime(2016, 1, 1, 0, 0, tzinfo=tzlocal()), 'Status': 'ACTIVE'}]}]})]
#
# Model execution details:
#
#  {'PredictorExecutions': [{'AlgorithmArn': 'arn:aws:forecast:::algorithm/ETS', 'TestWindows': [{'TestWindowStart': datetime.datetime(2015, 12, 8, 0, 0, tzinfo=tzlocal()), 'TestWindowEnd': datetime.datetime(2016, 1, 1, 0, 0, tzinfo=tzlocal()), 'Status': 'ACTIVE'}]}, {'AlgorithmArn': 'arn:aws:forecast:::algorithm/CNN-QR', 'TestWindows': [{'TestWindowStart': datetime.datetime(2015, 12, 8, 0, 0, tzinfo=tzlocal()), 'TestWindowEnd': datetime.datetime(2016, 1, 1, 0, 0, tzinfo=tzlocal()), 'Status': 'ACTIVE'}]}, {'AlgorithmArn': 'arn:aws:forecast:::algorithm/NPTS', 'TestWindows': [{'TestWindowStart': datetime.datetime(2015, 12, 8, 0, 0, tzinfo=tzlocal()), 'TestWindowEnd': datetime.datetime(2016, 1, 1, 0, 0, tzinfo=tzlocal()), 'Status': 'ACTIVE'}]}, {'AlgorithmArn': 'arn:aws:forecast:::algorithm/Prophet', 'TestWindows': [{'TestWindowStart': datetime.datetime(2015, 12, 8, 0, 0, tzinfo=tzlocal()), 'TestWindowEnd': datetime.datetime(2016, 1, 1, 0, 0, tzinfo=tzlocal()), 'Status': 'ACTIVE'}]}, {'AlgorithmArn': 'arn:aws:forecast:::algorithm/ARIMA', 'TestWindows': [{'TestWindowStart': datetime.datetime(2015, 12, 8, 0, 0, tzinfo=tzlocal()), 'TestWindowEnd': datetime.datetime(2016, 1, 1, 0, 0, tzinfo=tzlocal()), 'Status': 'ACTIVE'}]}, {'AlgorithmArn': 'arn:aws:forecast:::algorithm/Deep_AR_Plus', 'TestWindows': [{'TestWindowStart': datetime.datetime(2015, 12, 8, 0, 0, tzinfo=tzlocal()), 'TestWindowEnd': datetime.datetime(2016, 1, 1, 0, 0, tzinfo=tzlocal()), 'Status': 'ACTIVE'}]}]}

# %% [markdown]
# #### Error metrics for different models tested with auto ml

# %%
error_metrics = evaluate_backtesting_metrics(predictor_arn)

# if reading in previously saved backtest json result, uncomment below

#filename ='manning_automl_bt1_horizon24_metrics.json'
#error_metrics = read_json(RESULTS_DIR, filename)["PredictorEvaluationResults"]
df = plot_backtest_metrics(error_metrics)

# also show raw WQuantile loss bins data as these are not plotted on graph

df.loc[df['Metric'] == 'WQuantLosses',:]
# Out:
#          Metric  \
# 0  WQuantLosses
#
#                                                                                                                                                                NPTS  \
# 0  [{"Quantile": 0.9, "LossValue": 0.02063651665657977}, {"Quantile": 0.5, "LossValue": 0.062278599702156975}, {"Quantile": 0.1, "LossValue": 0.02514369892312955}]
#
#                                                                                                                                                                ARIMA  \
# 0  [{"Quantile": 0.9, "LossValue": 0.041156952141960204}, {"Quantile": 0.5, "LossValue": 0.08204920297244947}, {"Quantile": 0.1, "LossValue": 0.016080403657418297}]
#
#                                                                                                                                                      Deep_AR_Plus  \
# 0  [{"Quantile": 0.9, "LossValue": 0.0377132204915757}, {"Quantile": 0.5, "LossValue": 0.06811156090108098}, {"Quantile": 0.1, "LossValue": 0.03352957512683637}]
#
#                                                                                                                                                                 ETS  \
# 0  [{"Quantile": 0.9, "LossValue": 0.04180430124143294}, {"Quantile": 0.5, "LossValue": 0.08455909487719088}, {"Quantile": 0.1, "LossValue": 0.015895626636425873}]
#
#                                                                                                                                                             Prophet  \
# 0  [{"Quantile": 0.9, "LossValue": 0.04026632876521175}, {"Quantile": 0.5, "LossValue": 0.09203198454228698}, {"Quantile": 0.1, "LossValue": 0.021507499699081216}]
#
#                                                                                                                                                             CNN-QR
# 0  [{"Quantile": 0.9, "LossValue": 0.03128080182917267}, {"Quantile": 0.5, "LossValue": 0.07113695227853484}, {"Quantile": 0.1, "LossValue": 0.11464764786429016}]

# %% [markdown]
# ### Forecasting and saving results

# %%
forecast_arn = create_forecast(forecast_name, predictor_arn)

# %%
filters = {"item_id":"1"}
forecast_response = run_forecast_query_and_plot(forecast_arn, filters)


# if reading in previous forecast saved json , uncomment below
#filename ='manning_automl_bt1_horizon24_forecastResponse.json'
#forecast_response = read_json(RESULTS_DIR, filename)['Forecast']['Predictions']

df = create_forecast_plot(forecast_response)

# %%
args = [('manning_automl_bt1_horizon24_metrics.json', error_metrics), 
        ('manning_automl_bt1_horizon24_forecastResponse.json', forecast_response)]
               
save_results(basepath, *args)
# Out:
# saving to manning_automl_bt1_horizon24_metrics.json
# saving to manning_automl_bt1_horizon24_forecastResponse.json

# %% [markdown]
# #### Cleanup resources

# %%
kwargs = {'forecast':forecast_name,
'predictor':predictor_name
}
        
delete_training_forecast_resources(**kwargs)
# Out:
# No predictor job currently exists
# No forecast job currently exists

# %%
delete_dataset_resources(dataset_name)
# Out:
# No dataset group resource exists
# No dataset resource exists
